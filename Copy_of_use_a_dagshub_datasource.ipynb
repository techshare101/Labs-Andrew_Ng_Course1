# %% [markdown]
# <a href="https://colab.research.google.com/github/techshare101/Labs-Andrew_Ng_Course1/blob/main/Copy_of_use_a_dagshub_datasource.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Use the images datasource

# %%
# Install the DagsHub client
# !pip install -q dagshub
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.2/228.2 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.4/238.4 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 31.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.9/202.9 kB 11.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.9 MB/s eta 0:00:00
#   Building wheel for fusepy (setup.py) ... done

# %%
from dagshub.data_engine import datasources
ds = datasources.get('valentin2v2000/my-first-repo', 'images')
# Out:
#                                        ❗❗❗ AUTHORIZATION REQUIRED ❗❗❗
# Output()
# Open the following link in your browser to authorize the client:
# https://dagshub.com/login/oauth/authorize?state=1b3e150a-17af-432c-a7bc-60123bdbca11&client_id=32b60ba385aa7cecf24046d8195a71c07dd345d9657977863b52e7748e0f0f28&middleman_request_id=dbdd7d908d529e6c7218a9b727a1caca7929f4e1faf689b52ee699b0d9df49fb
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ## Query your data
# Datasources can be filtered using a pandas-like syntax.
#
# [For the full list of possible filters, see the docs](https://dagshub.com/docs/use_cases/data_engine/query_and_create_subsets).

# %%
# Example for simple query: get all data points with size larger than 1 byte
newQuery = ds["size"] > 1

# Display query results as data frame
newQuery.all().dataframe
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                        path  datapoint_id  \
# 0    train/000000000025.jpg      75065012
# 1    train/000000000165.jpg      75065013
# 2    train/000000000315.jpg      75065014
# 3    train/000000000395.jpg      75065015
# 4    train/000000000415.jpg      75065016
# ..                      ...           ...
# 128    val/000000062025.jpg      75065140
# 129    val/000000064495.jpg      75065141
# 130    val/000000087875.jpg      75065142
# 131    val/000000094185.jpg      75065143
# 132    val/000000105455.jpg      75065144
#
#                                   dagshub_download_url  \
# 0    https://dagshub.com/api/v1/repos/valentin2v200...
# 1    https://dagshub.com/api/v1/repos/valentin2v200...
# 2    https://dagshub.com/api/v1/repos/valentin2v200...
# 3    https://dagshub.com/api/v1/repos/valentin2v200...
# 4    https://dagshub.com/api/v1/repos/valentin2v200...
# ..                                                 ...
# 128  https://dagshub.com/api/v1/repos/valentin2v200...
# 129  https://dagshub.com/api/v1/repos/valentin2v200...
# 130  https://dagshub.com/api/v1/repos/valentin2v200...
# 131  https://dagshub.com/api/v1/repos/valentin2v200...
# 132  https://dagshub.com/api/v1/repos/valentin2v200...
#
#                                             annotation  \
# 0    703fae48da4335f9bb037dd85b8d5dafbe6b7df319c6a0...
# 1    d40211dd950211475ab970870a548245df236859b92f19...
# 2    fef8eed57246de1e977e36c20dcf9fc6e57c2d2bdacae5...
# 3    04e9f804d8abad204aaa809fc9b2d1483e7bc6bfda0f82...
# 4    60bfd57d3416a69b9d92de4f8607fe0ab0430434e904a1...
# ..                                                 ...
# 128  e5654f5ce0af61b8f07c4acf3dc149f51582e42f820747...
# 129  63441146555b57c5c0a7ca531363a1de4eb80917fe242a...
# 130  ee3c5eb96d6eb5ed881f92be4734ecac4bb19f14044bd8...
# 131  8c186624cdbebf15f4c1e6599469daf7e0d72bb22b09fa...
# 132  0a0f86cee4a0b97444c7f0efb788dea07bedae87abf137...
#
#                              categories custom_metadata    size    split  \
# 0                             "giraffe"            None  236591  "train"
# 1               "tie, scissors, person"            None  102857  "train"
# 2    "umbrella, chair, person, handbag"            None  128498  "train"
# 3                  "cell phone, person"            None  105015  "train"
# 4               "tennis racket, person"            None  223271  "train"
# ..                                  ...             ...     ...      ...
# 128         "cup, bottle, toilet, sink"            None  190140    "val"
# 129                     "parking meter"            None  251532    "val"
# 130                      "fire hydrant"            None   86815    "val"
# 131                "teddy bear, person"            None  223524    "val"
# 132                        "clock, car"            None  162940    "val"
#
#      valid_datapoint  year
# 0               True  2017
# 1               True  2017
# 2               True  2017
# 3               True  2017
# 4               True  2017
# ..               ...   ...
# 128             True  2017
# 129             True  2017
# 130             True  2017
# 131             True  2017
# 132             True  2017
#
# [133 rows x 10 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['datapoint_id'].plot(kind='hist', bins=20, title='datapoint_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['size'].plot(kind='hist', bins=20, title='size')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('custom_metadata').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('split').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='datapoint_id', y='size', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['datapoint_id']
#   ys = series['size']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_5.sort_values('datapoint_id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('custom_metadata')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='custom_metadata', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('datapoint_id')
# _ = plt.ylabel('size')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['datapoint_id']
#   ys = series['size']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_6.sort_values('datapoint_id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('split')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='split', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('datapoint_id')
# _ = plt.ylabel('size')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['datapoint_id']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'datapoint_id'}, axis=1)
#               .sort_values('datapoint_id', ascending=True))
#   xs = counted['datapoint_id']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_7.sort_values('datapoint_id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('custom_metadata')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='custom_metadata', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('datapoint_id')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['datapoint_id']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'datapoint_id'}, axis=1)
#               .sort_values('datapoint_id', ascending=True))
#   xs = counted['datapoint_id']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('datapoint_id', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('split')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='split', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('datapoint_id')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_9['datapoint_id'].plot(kind='line', figsize=(8, 4), title='datapoint_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['size'].plot(kind='line', figsize=(8, 4), title='size')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['split'].value_counts()
#     for x_label, grp in _df_11.groupby('custom_metadata')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('custom_metadata')
# _ = plt.ylabel('split')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_12['custom_metadata'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_12, x='datapoint_id', y='custom_metadata', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_13['split'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_13, x='datapoint_id', y='split', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_14['custom_metadata'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_14, x='size', y='custom_metadata', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_15['split'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_15, x='size', y='split', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# ## Additional Data Engine Capabilities
#
# Data Engine capabilities also includes: [data enrichments](https://dagshub.com/docs/use_cases/data_engine/enrich_datasource/), [visualizations](https://dagshub.com/docs/use_cases/data_engine/visualizing_datasets/), [annotations](https://dagshub.com/docs/use_cases/data_engine/annotate_data/), [creating datasets](https://dagshub.com/docs/use_cases/data_engine/query_and_create_subsets/) and [model training](https://dagshub.com/docs/use_cases/data_engine/train_model/).
